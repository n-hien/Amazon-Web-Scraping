# %%
import pandas as pd 

# read the collected data
df = pd.read_csv('amazon_earbuds.csv')

#check duplication
pd.concat(g for _, g in df.groupby("Asin") if len(g) > 1)
# Out:
#            Asin                                       Product Name   Price  \
# 157  B01MG62Z5M  JBL Tune 110 – In-Ear Kopfhörer mit verwicklun...    9,99
# 198  B01MG62Z5M  JBL Tune 110 – In-Ear Kopfhörer mit verwicklun...    9,99
# 93   B07HS1V2QK  JBL Free X In Ear Bluetooth Kopfhörer in Schwa...   74,99
# 117  B07HS1V2QK  JBL Free X In Ear Bluetooth Kopfhörer in Schwa...   74,99
# 104  B07NVFBK7J  Active Noise Cancelling Kopfhörer A9 Bluetooth...   29,99
# ..          ...                                                ...     ...
# 164  B09JQQDLXF                  Neu Apple AirPods (3. Generation)  198,90
# 52   B09KC97RZV  Bluetooth Kopfhörer, In Ear Ohrhörer HiFi Spor...   19,99
# 116  B09KC97RZV  Bluetooth Kopfhörer, In Ear Ohrhörer HiFi Spor...   19,99
# 268  B09KC97RZV  Bluetooth Kopfhörer, In Ear Ohrhörer HiFi Spor...   19,99
# 287  B09KC97RZV  Bluetooth Kopfhörer, In Ear Ohrhörer HiFi Spor...   19,99
#
#                 Rating  Number of Rating
# 157  4,3 von 5 Sternen            22.452
# 198  4,3 von 5 Sternen            22.452
# 93   4,2 von 5 Sternen             7.421
# 117  4,2 von 5 Sternen             7.421
# 104  4,5 von 5 Sternen           169.000
# ..                 ...               ...
# 164  3,9 von 5 Sternen           154.000
# 52   4,5 von 5 Sternen            17.000
# 116  4,5 von 5 Sternen            17.000
# 268  4,5 von 5 Sternen            17.000
# 287  4,5 von 5 Sternen            17.000
#
# [177 rows x 5 columns]

# %%
#remove duplicates by Asin 
df.drop_duplicates(subset=['Asin'], inplace = True) # now we have 250  rows instead of 381 as at the beginning
df
# Out:
#            Asin                                       Product Name   Price  \
# 0    B08LGRK6MT  Tiksounds Kopfhörer Kabellos, Bluetooth Kopfhö...   29,99
# 1    B08FB2V4GR  JBL Reflect Mini NC – Wasserdichte, True-Wirel...   99,99
# 2    B08C5HYHYB  Samsung Galaxy Buds Live, Kabellose Bluetooth-...   75,99
# 3    B08KDZ2NZX  Soundcore Life A1 In Ear Bluetooth Kopfhörer, ...   49,99
# 4    B08832CDT9  Amazon Brand - Eono Kabellose Ohrhörer, Eonobu...   29,99
# ..          ...                                                ...     ...
# 376  B098SNW1PJ  NURATRUE - True wireless earbuds with personal...  229,00
# 377  B097Q47KZ6  TAA7306/00 Philips kabellose Sport Kopfhörer, ...  133,06
# 378  B07W8G92L7  Philips In Ears Kopfhörer SHB2515WT/10 Kopfhör...   35,98
# 379  B099DNJD6T  Taopod Bluetooth Kopfhörer, Bluetooth 5.1 Kopf...   25,99
# 380  B009VAHHIS  Bluetooth Kopfhörer Kabellose Bluetooth 5.0 In...    9,99
#
#                 Rating  Number of Rating
# 0    4,3 von 5 Sternen             1.981
# 1    4,0 von 5 Sternen           248.000
# 2    4,4 von 5 Sternen            15.521
# 3    4,5 von 5 Sternen             3.627
# 4    4,1 von 5 Sternen             1.595
# ..                 ...               ...
# 376  4,1 von 5 Sternen            46.000
# 377  3,5 von 5 Sternen             4.000
# 378  4,1 von 5 Sternen           240.000
# 379  4,6 von 5 Sternen           165.000
# 380  4,6 von 5 Sternen           165.000
#
# [250 rows x 5 columns]

# %%
#now convert the datatype of price, Rating and Number of Rating to int or float for analysis purpose
df["Price"] = df["Price"].astype(str).str.replace(',', '.')
df["Price"] = pd.to_numeric(df['Price'])

df['Rating'] = df['Rating'].apply(lambda x: x.split()[0])
df["Rating"] = df["Rating"].astype(str).str.replace(',', '.')
df["Rating"] = pd.to_numeric(df['Rating'])

df["Number of Rating"] = df["Number of Rating"].astype(str).str.replace('.', '')
df["Number of Rating"] = pd.to_numeric(df['Number of Rating'])
# Out:
# <ipython-input-99-eda53302d0fa>:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Number of Rating"] = df["Number of Rating"].astype(str).str.replace('.', '')

# %%
#Print information about the data:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 380
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Asin              250 non-null    object
#  1   Product Name      250 non-null    object
#  2   Price             250 non-null    float64
#  3   Rating            250 non-null    float64
#  4   Number of Rating  250 non-null    int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 11.7+ KB

# %%
#Analyze the prices of earbuds
df['Price'].describe()
# Out:
# count    250.00000
# mean      73.25436
# std       72.46441
# min        6.79000
# 25%       29.99000
# 50%       41.19000
# 75%       92.49000
# max      619.80000
# Name: Price, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.boxplot(df['Price'])
plt.title("Boxplot Of Price")
plt.show()

#We can see the range of price is between 6.79 Euro and 619.80 Euro, mean is 73.25 Euro
#and

# %%
#Analyse the Product's Rating 
#Find out which products are top rated
#Let's assum that product which has more than 1000 of Rating is more reliable 
data = df[df['Number of Rating'] > 1000]
data.sort_values(['Rating'],axis=0, ascending=False)[:10]
# Out:
#            Asin                                       Product Name   Price  \
# 60   B09BZ3MKNW  Bluetooth Kopfhörer in Ear, Kopfhörer Kabellos...   28.05
# 283  B09JG67M85  Bluetooth Kopfhörer in Ear Kabellos Sport Blue...   25.99
# 258  B09FZBG3PV  Bluetooth Kopfhörer Sport, In Ear Kopfhörer Ka...   39.99
# 81   B09J8HTDHX  Kopfhörer Kabellos,Bluetooth in Ear Kopfhoerer...   21.33
# 8    B09GFL66SN  Bluetooth Kopfhörer In Ear, kopfhörer kabellos...   24.99
# 72   B09DSH1FVN  Bluetooth Kopfhörer Sport, In Ear Bluetooth 5....   39.99
# 13   B07PZR3PVB         Apple AirPods mit kabelgebundenem Ladecase  115.00
# 350  B09CKV8JSD  Bluetooth Kopfhörer, PUTARE HiFi Stereo Kopfhö...   29.74
# 82   B09BVZS1JX  Bluetooth Kopfhörer In Ear, Kopfhörer Kabellos...   25.49
# 14   B097BNRPLM  Bluetooth Kopfhörer In Ear, Kabellose Bluetoot...   29.99
#
#      Rating  Number of Rating
# 60      4.9              1268
# 283     4.8              1140
# 258     4.8              1080
# 81      4.8             14642
# 8       4.8             13553
# 72      4.7              1030
# 13      4.7            109104
# 350     4.7              1790
# 82      4.7              1547
# 14      4.7            109104

# %%
#Now see the top most rated products
df.sort_values(['Number of Rating'],axis=0, ascending=False)[:10]
# Out:
#            Asin                                       Product Name   Price  \
# 220  B07J2Z5DBM  TOZO T10 Bluetooth 5.0 Ohrhörer True Wireless ...   29.99
# 37   B07RGZ5NKS  TOZO T6 Bluetooth Kopfhörer In Ear Touch Contr...   35.99
# 14   B097BNRPLM  Bluetooth Kopfhörer In Ear, Kabellose Bluetoot...   29.99
# 13   B07PZR3PVB         Apple AirPods mit kabelgebundenem Ladecase  115.00
# 182  B07ZPML7NP                                  Apple AirPods Pro   38.99
# 157  B01MG62Z5M  JBL Tune 110 – In-Ear Kopfhörer mit verwicklun...    9.99
# 15   B07MCGZK3B  Soundcore by Anker Liberty Neo Bluetooth Kopfh...   45.99
# 282  B0748G1QLP  Bose SoundSport Free, vollkommen kabellose Spo...   29.99
# 2    B08C5HYHYB  Samsung Galaxy Buds Live, Kabellose Bluetooth-...   75.99
# 18   B0842QKN99  Samsung Galaxy Buds +, Kabellose Kopfhörer, 3 ...   99.00
#
#      Rating  Number of Rating
# 220     4.2            160276
# 37      4.4            114378
# 14      4.7            109104
# 13      4.7            109104
# 182     4.7             72317
# 157     4.3             22452
# 15      4.4             20956
# 282     4.3             16234
# 2       4.4             15521
# 18      4.6             14787
